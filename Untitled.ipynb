# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\mmath\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mmath\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mmath\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mmath\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\mmath\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\mmath\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in c:\users\mmath\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\mmath\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\mmath\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\mmath\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\mmath\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\mmath\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mmath\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six in c:\users\mmath\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mmath\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Mobile Phone Price Prediction

# %%
df = pd.read_csv("data/mobile_price_prediction_data.csv")

# %%
df.head()
# Out:
#    Ratings  RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0      4.3  4.0  128.0         6.00           48       13.0           4000
# 1      3.4  6.0   64.0         4.50           48       12.0           4000
# 2      4.3  4.0    4.0         4.50           64       16.0           4000
# 3      4.4  6.0   64.0         6.40           48       15.0           3800
# 4      4.5  6.0  128.0         6.18           35       15.0           3800
#
#    Price
# 0  24999
# 1  15999
# 2  15000
# 3  18999
# 4  18999

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.pairplot(data = df)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.boxplot(data = df)
plt.yscale("log")

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum(axis=0)
# Out:
# Ratings          0
# RAM              0
# ROM              0
# Mobile_Size      0
# Primary_Cam      0
# Selfi_Cam        0
# Battery_Power    0
# Price            0
# dtype: int64

# %%
def remove_outliers_iqr(df, target_columns):
    df_cleaned = df.copy()
    
    for column in target_columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        
        df_cleaned = df_cleaned[~((df_cleaned[column] < (Q1 - 1.5 * IQR)) | (df_cleaned[column] > (Q3 + 1.5 * IQR)))]
    
    return df_cleaned

# %%
cleaned_df = remove_outliers_iqr(df, target_columns=['Mobile_Size', 'ROM'])

# %%
cleaned_df.head()
# Out:
#     Ratings  RAM   ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 1       3.4  6.0  64.0         4.50           48       12.0           4000
# 2       4.3  4.0   4.0         4.50           64       16.0           4000
# 3       4.4  6.0  64.0         6.40           48       15.0           3800
# 10      3.9  6.0  32.0         4.54           64        8.0           4100
# 11      3.8  6.0  32.0         4.50           64        8.0           1050
#
#     Price
# 1   15999
# 2   15000
# 3   18999
# 10   1099
# 11   1299

# %%
sns.pairplot(data = cleaned_df)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.boxplot(data = cleaned_df)
plt.yscale("log")
